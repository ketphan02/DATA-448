# %% [markdown]
# # Section 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

import sys
sys.path.append('../../')

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
plt.style.use('ggplot')
sns.set_palette('Set2')

# %% [markdown]
# ## Data

# %%
team_a = pd.DataFrame({
    'Name': [ 'Brooke', 'Alex', 'Jean' ],
    'Website': [ 2, 5, 1],
    'Database': [1, 4, 2],
    'Communication': [2, 5, 2],
    'Time': [2, 4, 1]
})

display(team_a)
# Out:
#      Name  Website  Database  Communication  Time
# 0  Brooke        2         1              2     2
# 1    Alex        5         4              5     4
# 2    Jean        1         2              2     1

# %%
team_b = pd.DataFrame({
    'Name': [ 'Sky', 'Jesse', 'Sam' ],
    'Website': [2, 1, 4],
    'Database': [1, 1, 5],
    'Communication': [2, 1, 4],
    'Time': [1, 2, 4]
})

display(team_b)
# Out:
#     Name  Website  Database  Communication  Time
# 0    Sky        2         1              2     1
# 1  Jesse        1         1              1     2
# 2    Sam        4         5              4     4

# %%
team_c = pd.DataFrame({
    'Name': [ 'Andy', 'Cole', 'Blake' ],
    'Website': [2, 5, 2],
    'Database': [2, 4, 2],
    'Communication': [1, 5, 2],
    'Time': [2, 4, 2]
})

display(team_c)
# Out:
#     Name  Website  Database  Communication  Time
# 0   Andy        2         2              1     2
# 1   Cole        5         4              5     4
# 2  Blake        2         2              2     2

# %%
team_d = pd.DataFrame({
    'Name': [ 'Max', 'Devin', 'Val' ],
    'Website': [3, 2, 3],
    'Database': [4, 3, 3],
    'Communication': [3, 4, 3],
    'Time': [3, 3, 3]
})

display(team_d)
# Out:
#     Name  Website  Database  Communication  Time
# 0    Max        3         4              3     3
# 1  Devin        2         3              4     3
# 2    Val        3         3              3     3

# %%
team_e = pd.DataFrame({
    'Name': [ 'Baker', 'Jan', 'Avis' ],
    'Website': [2, 2, 1],
    'Database': [2, 2, 1],
    'Communication': [1, 2, 2],
    'Time': [2, 2, 1]
})

display(team_e)
# Out:
#     Name  Website  Database  Communication  Time
# 0  Baker        2         2              1     2
# 1    Jan        2         2              2     2
# 2   Avis        1         1              2     1

# %%
team_f = pd.DataFrame({
    'Name': [ 'August', 'Louis', 'Ray' ],
    'Website': [5, 4, 4],
    'Database': [4, 5, 4],
    'Communication': [5, 4, 3],
    'Time': [4, 4, 4]
})

display(team_f)
# Out:
#      Name  Website  Database  Communication  Time
# 0  August        5         4              5     4
# 1   Louis        4         5              4     4
# 2     Ray        4         4              3     4

# %%
class_avg_stack = pd.DataFrame.from_records([{
    'Name': 'Class average',
    'Website': 7,
    'Database': 6,
    'Communication': 6.5,
    'Time': 8,
}])

display(class_avg_stack)
# Out:
#             Name  Website  Database  Communication  Time
# 0  Class average        7         6            6.5     8

# %%
class_avg_group = pd.DataFrame.from_records([{
    'Name': 'Class average',
    'Website': 2.7,
    'Database': 2.4,
    'Communication': 2.5,
    'Time': 3,
}])

display(class_avg_group)
# Out:
#             Name  Website  Database  Communication  Time
# 0  Class average      2.7       2.4            2.5     3

# %% [markdown]
# ## Visualization

# %%
from functions.section1 import multi_stack

# Q15 strong students can mentor weak students
# Updated the data to make mentors stand out more
# ANSWER: SCENARIO 1

# In TEAM A, ALEX is a mentor
multi_stack.viz(team_a, class_avg_stack, 'TEAM A', '../../visualizations/VizSkills/p3s/mentor/teamA.png')
# In TEAM B, SAM is a mentor
multi_stack.viz(team_b, class_avg_stack, 'TEAM B', '../../visualizations/VizSkills/p3s/mentor/teamB.png')
# In TEAM C, COLE is a mentor
multi_stack.viz(team_c, class_avg_stack, 'TEAM C', '../../visualizations/VizSkills/p3s/mentor/teamC.png')
# In TEAM D, everyone is mediocre
multi_stack.viz(team_d, class_avg_stack, 'TEAM D', '../../visualizations/VizSkills/p3s/mentor/teamD.png')
# In TEAM E, everyone is weak
multi_stack.viz(team_e, class_avg_stack, 'TEAM E', '../../visualizations/VizSkills/p3s/mentor/teamE.png')
# In TEAM F, everyone is strong
multi_stack.viz(team_f, class_avg_stack, 'TEAM F', '../../visualizations/VizSkills/p3s/mentor/teamF.png')

# %%
from functions.section1 import multi_multi_bar as mmb

# Q30 strong students can mentor weak student

mmb.viz(team_a, class_avg_group, 'TEAM A', '../../visualizations/VizSkills/p3g/mentor/teamA.png')
mmb.viz(team_b, class_avg_group, 'TEAM B', '../../visualizations/VizSkills/p3g/mentor/teamB.png')
mmb.viz(team_c, class_avg_group, 'TEAM C', '../../visualizations/VizSkills/p3g/mentor/teamC.png')
mmb.viz(team_d, class_avg_group, 'TEAM D', '../../visualizations/VizSkills/p3g/mentor/teamD.png')
mmb.viz(team_e, class_avg_group, 'TEAM E', '../../visualizations/VizSkills/p3g/mentor/teamE.png')
mmb.viz(team_f, class_avg_group, 'TEAM F', '../../visualizations/VizSkills/p3g/mentor/teamF.png')
