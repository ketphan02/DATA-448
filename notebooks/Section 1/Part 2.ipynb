# %% [markdown]
# # Section 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

import sys
sys.path.append('../../')

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
plt.style.use('ggplot')
sns.set_palette('Set2')

# %% [markdown]
# ## Data

# %%
# Not Needed
team_a = pd.DataFrame({
    'Name': [ 'Brooke', 'Alex', 'Jean' ],
    'Website': [ 3, 2, 1], # Third Condition
    'Database': [4, 5, 3], # First Condition
    'Communication': [5, 2, 3], # Fourth Condition
    'Time': [3, 4, 2] # Second Condition
})

display(team_a)
# Out:
#      Name  Website  Database  Communication  Time
# 0  Brooke        3         4              5     3
# 1    Alex        2         5              2     4
# 2    Jean        1         3              3     2

# %%
# Not Needed
team_b = pd.DataFrame({
    'Name': [ 'Sky', 'Jesse', 'Sam' ],
    'Website': [4, 3, 2],
    'Database': [2, 3, 3],
    'Communication': [2, 5, 2],
    'Time': [3, 4, 3]
})

display(team_b)
# Out:
#     Name  Website  Database  Communication  Time
# 0    Sky        4         2              2     3
# 1  Jesse        3         3              5     4
# 2    Sam        2         3              2     3

# %%
team_c = pd.DataFrame({
    'Name': [ 'Andy', 'Sid', 'Blake', 'Cole'],
    'Website': [4, 4, 4, 1], # Fourth Condition
    'Database': [4, 4, 5, 3], # First Condition
    'Communication': [5, 4, 1, 3], # Second Condition
    'Time': [5, 4, 1, 2] # Third Condition
})

display(team_c)
# Out:
#     Name  Website  Database  Communication  Time
# 0   Andy        4         4              5     5
# 1    Sid        4         4              4     4
# 2  Blake        4         5              1     1
# 3   Cole        1         3              3     2

# %%
team_d = pd.DataFrame({
    'Name': [ 'Max', 'Devin', 'Val'],
    'Website': [3, 4, 3], # Fourth Condition
    'Database': [2, 3, 3], # First Condition
    'Communication': [5, 4, 3], # Second Condition
    'Time': [5, 4, 4] # Third Condition
})

display(team_c)
# Out:
#     Name  Website  Database  Communication  Time
# 0   Andy        4         4              5     5
# 1    Sid        4         4              4     4
# 2  Blake        4         5              1     1
# 3   Cole        1         3              3     2

# %%
class_avg = pd.DataFrame.from_records([{
    'Name': 'Class average',
    'Website': 3,
    'Database': 2.4,
    'Communication': 2.7,
    'Time': 2.5,
}])

display(class_avg)
# Out:
#             Name  Website  Database  Communication  Time
# 0  Class average        3       2.4            2.7   2.5

# %% [markdown]
# ## Visualization

# %% [markdown]
# # Part 2 - Move a Student: Stack 4vs3

# %%
from functions.section1 import single_stack

# Q10 Move someone strong / First Condition
# Answer: Blake should be moved
# calculation in google sheet
single_stack.viz(team_c, class_avg, 'Database', 'TEAM A', '../../visualizations/VizSkills/p2s/q1a.png', max_num=20)
single_stack.viz(team_d, class_avg, 'Database', 'TEAM B', '../../visualizations/VizSkills/p2s/q1b.png')

# %%
# Q12 Move someone medicore
# Answer: Cole should be moved
single_stack.viz(team_c, class_avg, 'Communication', 'TEAM A', '../../visualizations/VizSkills/p2s/q2a.png', max_num=20)
single_stack.viz(team_d, class_avg, 'Communication', 'TEAM B', '../../visualizations/VizSkills/p2s/q2b.png')

# %%
# Q11 Move someone weak
# Answer: Blake should be moved
single_stack.viz(team_c, class_avg, 'Time', 'TEAM A', '../../visualizations/VizSkills/p2s/q3a.png', max_num=20)
single_stack.viz(team_d, class_avg, 'Time', 'TEAM B', '../../visualizations/VizSkills/p2s/q3b.png')

# %%
# Q9 No one need to move
# Answer: No one need to move
single_stack.viz(team_c, class_avg, 'Website', 'TEAM A', '../../visualizations/VizSkills/p2s/q4a.png', max_num=20)
single_stack.viz(team_d, class_avg, 'Website', 'TEAM B', '../../visualizations/VizSkills/p2s/q4b.png')

# %% [markdown]
# # Part 2 - Move a Student: Group 4vs3

# %%
from functions.section1 import multi_bar

# Q 25
# Move someone strong
# Answer: Blake should be moved
# calculation in google sheet
multi_bar.viz(team_c, class_avg, 'Database', 'TEAM A', '../../visualizations/VizSkills/p2g/q1a.png')
multi_bar.viz(team_d, class_avg, 'Database', 'TEAM B', '../../visualizations/VizSkills/p2g/q1b.png')

# %%
# replace Q26 with this
# Q26
# Move someone medicore
# Answer: Cole should be moved
multi_bar.viz(team_c, class_avg, 'Communication', 'TEAM A', '../../visualizations/VizSkills/p2g/q2a.png')
multi_bar.viz(team_d, class_avg, 'Communication', 'TEAM B', '../../visualizations/VizSkills/p2g/q2b.png')

# %%
# Q28
# Move someone weak
# Answer: Blake should be moved
multi_bar.viz(team_c, class_avg, 'Time', 'TEAM A', '../../visualizations/VizSkills/p2g/q3a.png')
multi_bar.viz(team_d, class_avg, 'Time', 'TEAM B', '../../visualizations/VizSkills/p2g/q3b.png')

# %%
# Q27
# No one need to move
# Answer: No one need to move
multi_bar.viz(team_c, class_avg, 'Website', 'TEAM A', '../../visualizations/VizSkills/p2s/q4a.png')
multi_bar.viz(team_d, class_avg, 'Website', 'TEAM B', '../../visualizations/VizSkills/p2s/q4b.png')
