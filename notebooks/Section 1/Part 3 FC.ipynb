# %% [markdown]
# # Section 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

import sys
sys.path.append('../../')

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
plt.style.use('ggplot')
sns.set_palette('Set2')

# %% [markdown]
# ## Data

# %%
team_a = pd.DataFrame({
    'Name': [ 'Brooke', 'Alex', 'Jean' ],
    'Website': [ 2, 5, 3],
    'Database': [1, 4, 2],
    'Communication': [1, 5, 2],
    'Time': [2, 4, 3]
})

display(team_a)
# Out:
#      Name  Website  Database  Communication  Time
# 0  Brooke        2         1              1     2
# 1    Alex        5         4              5     4
# 2    Jean        3         2              2     3

# %%
team_b = pd.DataFrame({
    'Name': [ 'Sky', 'Jesse', 'Sam' ],
    'Website': [2, 3, 4],
    'Database': [2, 2, 4],
    'Communication': [3, 2, 4],
    'Time': [1, 2, 4]
})

display(team_b)
# Out:
#     Name  Website  Database  Communication  Time
# 0    Sky        2         2              3     1
# 1  Jesse        3         2              2     2
# 2    Sam        4         4              4     4

# %%
team_c = pd.DataFrame({
    'Name': [ 'Andy', 'Cole', 'Blake' ],
    'Website': [2, 4, 2],
    'Database': [2, 4, 3],
    'Communication': [1, 5, 1],
    'Time': [3, 5, 3]
})

display(team_c)
# Out:
#     Name  Website  Database  Communication  Time
# 0   Andy        2         2              1     3
# 1   Cole        4         4              5     5
# 2  Blake        2         3              1     3

# %%
team_d = pd.DataFrame({
    'Name': [ 'Max', 'Devin', 'Val' ],
    'Website': [2, 3, 4],
    'Database': [1, 2, 2],
    'Communication': [2, 2, 3],
    'Time': [1, 4, 1]
})

display(team_d)
# Out:
#     Name  Website  Database  Communication  Time
# 0    Max        2         1              2     1
# 1  Devin        3         2              2     4
# 2    Val        4         2              3     1

# %%
team_e = pd.DataFrame({
    'Name': [ 'Baker', 'Jan', 'Avis' ],
    'Website': [4, 5, 4],
    'Database': [4, 4, 5],
    'Communication': [4, 5, 5],
    'Time': [3, 4, 4]
})

display(team_e)
# Out:
#     Name  Website  Database  Communication  Time
# 0  Baker        4         4              4     3
# 1    Jan        5         4              5     4
# 2   Avis        4         5              5     4

# %%
team_f = pd.DataFrame({
    'Name': [ 'August', 'Louis', 'Ray' ],
    'Website': [4, 1, 1],
    'Database': [2, 4, 2],
    'Communication': [3, 1, 2],
    'Time': [3, 3, 1]
})

display(team_f)
# Out:
#      Name  Website  Database  Communication  Time
# 0  August        4         2              3     3
# 1   Louis        1         4              1     3
# 2     Ray        1         2              2     1

# %%
class_avg_stack = pd.DataFrame.from_records([{
    'Name': 'Class average',
    'Website': 7,
    'Database': 6,
    'Communication': 6.5,
    'Time': 8,
}])

display(class_avg_stack)
# Out:
#             Name  Website  Database  Communication  Time
# 0  Class average        7         6            6.5     8

# %%
class_avg_group = pd.DataFrame.from_records([{
    'Name': 'Class average',
    'Website': 2.7,
    'Database': 2.4,
    'Communication': 2.5,
    'Time': 3,
}])

display(class_avg_group)
# Out:
#             Name  Website  Database  Communication  Time
# 0  Class average      2.7       2.4            2.5     3

# %% [markdown]
# ## Visualization

# %%
from functions.section1 import multi_stack

# Q13 Strong skills be spread out
multi_stack.viz(team_a, class_avg_stack, 'TEAM A', '../../visualizations/VizSkills/p3s/strong/teamA.png')
multi_stack.viz(team_b, class_avg_stack, 'TEAM B', '../../visualizations/VizSkills/p3s/strong/teamB.png')
multi_stack.viz(team_c, class_avg_stack, 'TEAM C', '../../visualizations/VizSkills/p3s/strong/teamC.png')
multi_stack.viz(team_d, class_avg_stack, 'TEAM D', '../../visualizations/VizSkills/p3s/strong/teamD.png')
multi_stack.viz(team_e, class_avg_stack, 'TEAM E', '../../visualizations/VizSkills/p3s/strong/teamE.png')
multi_stack.viz(team_f, class_avg_stack, 'TEAM F', '../../visualizations/VizSkills/p3s/strong/teamF.png')

# %%
from functions.section1 import multi_multi_bar as mmb

mmb.viz(team_a, class_avg_group, 'TEAM A', '../../visualizations/VizSkills/p3g/strong/teamA.png')
mmb.viz(team_b, class_avg_group, 'TEAM B', '../../visualizations/VizSkills/p3g/strong/teamB.png')
mmb.viz(team_c, class_avg_group, 'TEAM C', '../../visualizations/VizSkills/p3g/strong/teamC.png')
mmb.viz(team_d, class_avg_group, 'TEAM D', '../../visualizations/VizSkills/p3g/strong/teamD.png')
mmb.viz(team_e, class_avg_group, 'TEAM E', '../../visualizations/VizSkills/p3g/strong/teamE.png')
mmb.viz(team_f, class_avg_group, 'TEAM F', '../../visualizations/VizSkills/p3g/strong/teamF.png')
