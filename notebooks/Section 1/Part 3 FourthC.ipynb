# %% [markdown]
# # Section 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

import sys
sys.path.append('../../')

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
plt.style.use('ggplot')
sns.set_palette('Set2')

# %% [markdown]
# ## Data

# %%
team_a = pd.DataFrame({
    'Name': [ 'Brooke', 'Alex', 'Jean' ],
    'Website': [ 1, 2, 1],
    'Database': [4, 3, 4],
    'Communication': [3, 5, 3],
    'Time': [1, 2, 2]
})

display(team_a)
# Out:
#      Name  Website  Database  Communication  Time
# 0  Brooke        1         4              3     1
# 1    Alex        2         3              5     2
# 2    Jean        1         4              3     2

# %%
team_b = pd.DataFrame({
    'Name': [ 'Sky', 'Jesse', 'Sam' ],
    'Website': [2, 4, 5],
    'Database': [2, 1, 2],
    'Communication': [2, 4, 5],
    'Time': [2, 1, 2]
})

display(team_b)
# Out:
#     Name  Website  Database  Communication  Time
# 0    Sky        2         2              2     2
# 1  Jesse        4         1              4     1
# 2    Sam        5         2              5     2

# %%
team_c = pd.DataFrame({
    'Name': [ 'Andy', 'Cole', 'Blake' ],
    'Website': [4, 3, 4],
    'Database': [2, 1, 2],
    'Communication': [1, 2, 2],
    'Time': [3, 5, 3]
})

display(team_c)
# Out:
#     Name  Website  Database  Communication  Time
# 0   Andy        4         2              1     3
# 1   Cole        3         1              2     5
# 2  Blake        4         2              2     3

# %%
team_d = pd.DataFrame({
    'Name': [ 'Max', 'Devin', 'Val' ],
    'Website': [2, 5, 1],
    'Database': [4, 1, 3],
    'Communication': [4, 1, 3],
    'Time': [2, 4, 5]
})

display(team_d)
# Out:
#     Name  Website  Database  Communication  Time
# 0    Max        2         4              4     2
# 1  Devin        5         1              1     4
# 2    Val        1         3              3     5

# %%
team_e = pd.DataFrame({
    'Name': [ 'Baker', 'Jan', 'Avis' ],
    'Website': [1, 2, 5],
    'Database': [2, 1, 5],
    'Communication': [2, 4, 1],
    'Time': [4, 1, 2]
})

display(team_e)
# Out:
#     Name  Website  Database  Communication  Time
# 0  Baker        1         2              2     4
# 1    Jan        2         1              4     1
# 2   Avis        5         5              1     2

# %%
team_f = pd.DataFrame({
    'Name': [ 'August', 'Louis', 'Ray' ],
    'Website': [1, 1, 5],
    'Database': [2, 4, 2],
    'Communication': [5, 1, 2],
    'Time': [2, 4, 1]
})

display(team_f)
# Out:
#      Name  Website  Database  Communication  Time
# 0  August        1         2              5     2
# 1   Louis        1         4              1     4
# 2     Ray        5         2              2     1

# %%
class_avg_stack = pd.DataFrame.from_records([{
    'Name': 'Class average',
    'Website': 7,
    'Database': 6,
    'Communication': 6.5,
    'Time': 8,
}])

display(class_avg_stack)
# Out:
#             Name  Website  Database  Communication  Time
# 0  Class average        7         6            6.5     8

# %%
class_avg_group = pd.DataFrame.from_records([{
    'Name': 'Class average',
    'Website': 2.7,
    'Database': 2.4,
    'Communication': 2.5,
    'Time': 3,
}])

display(class_avg_group)
# Out:
#             Name  Website  Database  Communication  Time
# 0  Class average      2.7       2.4            2.5     3

# %% [markdown]
# ## Visualization

# %%
from functions.section1 import multi_stack

multi_stack.viz(team_a, class_avg_stack, 'TEAM A', '../../visualizations/VizSkills/p3s/different/teamA.png')
multi_stack.viz(team_b, class_avg_stack, 'TEAM B', '../../visualizations/VizSkills/p3s/different/teamB.png')
multi_stack.viz(team_c, class_avg_stack, 'TEAM C', '../../visualizations/VizSkills/p3s/different/teamC.png')
multi_stack.viz(team_d, class_avg_stack, 'TEAM D', '../../visualizations/VizSkills/p3s/different/teamD.png')
multi_stack.viz(team_e, class_avg_stack, 'TEAM E', '../../visualizations/VizSkills/p3s/different/teamE.png')
multi_stack.viz(team_f, class_avg_stack, 'TEAM F', '../../visualizations/VizSkills/p3s/different/teamF.png')

# %%
from functions.section1 import multi_multi_bar as mmb

mmb.viz(team_a, class_avg_group, 'TEAM A', '../../visualizations/VizSkills/p3g/different/teamA.png')
mmb.viz(team_b, class_avg_group, 'TEAM B', '../../visualizations/VizSkills/p3g/different/teamB.png')
mmb.viz(team_c, class_avg_group, 'TEAM C', '../../visualizations/VizSkills/p3g/different/teamC.png')
mmb.viz(team_d, class_avg_group, 'TEAM D', '../../visualizations/VizSkills/p3g/different/teamD.png')
mmb.viz(team_e, class_avg_group, 'TEAM E', '../../visualizations/VizSkills/p3g/different/teamE.png')
mmb.viz(team_f, class_avg_group, 'TEAM F', '../../visualizations/VizSkills/p3g/different/teamF.png')
