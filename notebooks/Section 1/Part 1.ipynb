# %% [markdown]
# # Section 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

import sys
sys.path.append('../../')

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
plt.style.use('ggplot')
sns.set_palette('Set2')

# %% [markdown]
# ## Data

# %%
team_a = pd.DataFrame({
    'Name': [ 'Brooke', 'Alex', 'Jean' ],
    'Website': [ 3, 4, 3],
    'Database': [3, 3, 3],
    'Communication': [3, 2, 2],
    'Time': [3, 1, 3]
})

display(team_a)
# Out:
#      Name  Website  Database  Communication  Time
# 0  Brooke        3         3              3     3
# 1    Alex        4         3              2     1
# 2    Jean        3         3              2     3

# %%
team_b = pd.DataFrame({
    'Name': [ 'Sky', 'Jesse', 'Sam' ],
    'Website': [5, 4, 4],
    'Database': [2, 1, 2],
    'Communication': [4, 2, 5],
    'Time': [2, 3, 1]
})

display(team_b)
# Out:
#     Name  Website  Database  Communication  Time
# 0    Sky        5         2              4     2
# 1  Jesse        4         1              2     3
# 2    Sam        4         2              5     1

# %%
team_c = pd.DataFrame({
    'Name': [ 'Andy', 'Cole', 'Blake' ],
    'Website': [2, 3, 3],
    'Database': [2, 1, 3],
    'Communication': [3, 2, 5],
    'Time': [3, 2, 3]
})

display(team_c)
# Out:
#     Name  Website  Database  Communication  Time
# 0   Andy        2         2              3     3
# 1   Cole        3         1              2     2
# 2  Blake        3         3              5     3

# %%
team_d = pd.DataFrame({
    'Name': [ 'Max', 'Devin', 'Val', 'Sid' ],
    'Website': [2, 2, 2, 1],
    'Database': [2, 1, 4, 4],
    'Communication': [1, 2, 2, 2],
    'Time': [1, 3, 3, 4]
})

display(team_d)
# Out:
#     Name  Website  Database  Communication  Time
# 0    Max        2         2              1     1
# 1  Devin        2         1              2     3
# 2    Val        2         4              2     3
# 3    Sid        1         4              2     4

# %%
team_d_q21 = pd.DataFrame({
    'Name': [ 'Max', 'Devin', 'Val', 'Sid' ],
    'Website': [2, 2, 2, 1],
    'Database': [2, 1, 4, 4],
    'Communication': [1, 2, 2, 2],
    'Time': [4, 3, 3, 4]
})

display(team_d_q21)
# Out:
#     Name  Website  Database  Communication  Time
# 0    Max        2         2              1     4
# 1  Devin        2         1              2     3
# 2    Val        2         4              2     3
# 3    Sid        1         4              2     4

# %%
class_avg = {
    'Website': 3,
    'Database': 2.4,
    'Communication': 2.7,
    'Time': 2.5,
}

display(class_avg)
# Out:
# {'Website': 3, 'Database': 2.4, 'Communication': 2.7, 'Time': 2.5}

# %% [markdown]
# ## Visualization

# %% [markdown]
# # Part 1 - Identify Best Team: Stacked 3vs3

# %%
from functions.section1 import single_stack

# Q1 Website 
# A and B are both above the mean
# Answer: Team B
single_stack.viz(team_a, class_avg, 'Website', 'TEAM A', '../../visualizations/VizSkills/p13v3s/q1a.png')
single_stack.viz(team_b, class_avg, 'Website', 'TEAM B', '../../visualizations/VizSkills/p13v3s/q1b.png')

# %%
# Q2 Database
# A is above the mean and B is below the mean
# Answer: Team A
single_stack.viz(team_a, class_avg, 'Database', 'TEAM A', '../../visualizations/VizSkills/p13v3s/q2a.png')
single_stack.viz(team_b, class_avg, 'Database', 'TEAM B', '../../visualizations/VizSkills/p13v3s/q2b.png')

# %%
# Q3 Communication
# A is below the mean and B is above
# Answer: Team B
single_stack.viz(team_a, class_avg, 'Communication', 'TEAM A', '../../visualizations/VizSkills/p13v3s/q3a.png')
single_stack.viz(team_b, class_avg, 'Communication', 'TEAM B', '../../visualizations/VizSkills/p13v3s/q3b.png')

# %%
# Q4 Time
# A and B both below
# Answer: Team A
# Team A has an average skill of 2.33 (7/3)
# Team B has an average skill of 2 (6/3)
single_stack.viz(team_a, class_avg, 'Time', 'TEAM B', '../../visualizations/VizSkills/p13v3s/q4a.png')
single_stack.viz(team_b, class_avg, 'Time', 'TEAM A', '../../visualizations/VizSkills/p13v3s/q4b.png')

# %% [markdown]
# # Part 1 - Identify Best Team: Stacked 4vs3

# %%
# Q5 Website
# A and B are both below the mean
# Answer: Team E
# Team E has an average skill of 2.67 (8/3)
# Team F has an average skill of 1.75 (7/4)
single_stack.viz(team_c, class_avg, 'Website', 'TEAM E', '../../visualizations/VizSkills/p13v4s/q1a.png')
single_stack.viz(team_d, class_avg, 'Website', 'TEAM F', '../../visualizations/VizSkills/p13v4s/q1b.png', max_num=20)

# %%
# Q6 Database
# E is below the mean and F is above the mean
# Answer: Team F
# Team E has an average skill of 2 (6/3)
# Team F has an average skill of 2.75 (11/4)
single_stack.viz(team_c, class_avg, 'Database', 'TEAM E', '../../visualizations/VizSkills/p13v4s/q2a.png')
single_stack.viz(team_d, class_avg, 'Database', 'TEAM F', '../../visualizations/VizSkills/p13v4s/q2b.png', max_num=20)

# %%
# Q7 Communication
# E is above the mean and F is below the mean
# Answer: Team E
single_stack.viz(team_c, class_avg, 'Communication', 'TEAM E', '../../visualizations/VizSkills/p13v4s/q3a.png')
single_stack.viz(team_d, class_avg, 'Communication', 'TEAM F', '../../visualizations/VizSkills/p13v4s/q3b.png', max_num=20)

# %%
# Q8 Time
# both above the mean
# Answer: Team F
single_stack.viz(team_c, class_avg, 'Time', 'TEAM E', '../../visualizations/VizSkills/p13v4s/q4a.png')
single_stack.viz(team_d, class_avg, 'Time', 'TEAM F', '../../visualizations/VizSkills/p13v4s/q4b.png', max_num=20)

# %% [markdown]
# # Part 1 - Identify Best Team: Group 3vs3

# %%
from functions.section1 import single_bar

# Q17 Website
# C and D are both above the mean
# Answer: Team D
single_bar.viz(team_a, class_avg, 'Website', 'TEAM C', '../../visualizations/VizSkills/p13v3g/q1a.png')
single_bar.viz(team_b, class_avg, 'Website', 'TEAM D', '../../visualizations/VizSkills/p13v3g/q1b.png')

# %%
# Q18 Database
# C is above the mean and D is below the mean
# Answer: Team C
single_bar.viz(team_a, class_avg, 'Database', 'TEAM C', '../../visualizations/VizSkills/p13v3g/q2a.png')
single_bar.viz(team_b, class_avg, 'Database', 'TEAM D', '../../visualizations/VizSkills/p13v3g/q2b.png')

# %%
# Q20 Communication
# C is below the mean and D is above the mean
# Answer: Team D
single_bar.viz(team_a, class_avg, 'Communication', 'TEAM C', '../../visualizations/VizSkills/p13v3g/q3a.png')
single_bar.viz(team_b, class_avg, 'Communication', 'TEAM D', '../../visualizations/VizSkills/p13v3g/q3b.png')

# %%
# Q19 Time
# C and D are both below
# Answer: Team C
single_bar.viz(team_a, class_avg, 'Time', 'TEAM C', '../../visualizations/VizSkills/p13v3g/q4a.png')
single_bar.viz(team_b, class_avg, 'Time', 'TEAM D', '../../visualizations/VizSkills/p13v3g/q4b.png')

# %% [markdown]
# # Part 1 - Identify Best Team: Group 3vs4

# %%
# Q24 Website
# G and H are both below the mean
# Answer: Team G
single_bar.viz(team_c, class_avg, 'Website', 'TEAM G', '../../visualizations/VizSkills/p13v4g/q1a.png')
single_bar.viz(team_d, class_avg, 'Website', 'TEAM H', '../../visualizations/VizSkills/p13v4g/q1b.png')

# %%
# Q22 Database
# G is below the mean and H is above the mean
# Answer: Team H
single_bar.viz(team_c, class_avg, 'Database', 'TEAM G', '../../visualizations/VizSkills/p13v4g/q2a.png')
single_bar.viz(team_d, class_avg, 'Database', 'TEAM H', '../../visualizations/VizSkills/p13v4g/q2b.png')

# %%
# Q23 Communication
# G is below the mean and H is above the mean
# Answer: Team G
single_bar.viz(team_c, class_avg, 'Communication', 'TEAM G', '../../visualizations/VizSkills/p13v4g/q3a.png')
single_bar.viz(team_d, class_avg, 'Communication', 'TEAM H', '../../visualizations/VizSkills/p13v4g/q3b.png')

# %%
# Q21 Time (FIXED)
# G and H is above the mean
# Answer: Team G
single_bar.viz(team_c, class_avg, 'Time', 'TEAM G', '../../visualizations/VizSkills/p13v4g/q4a.png')
# (Issue) change Team H
single_bar.viz(team_d_q21, class_avg, 'Time', 'TEAM H', '../../visualizations/VizSkills/p13v4g/q4b.png')
