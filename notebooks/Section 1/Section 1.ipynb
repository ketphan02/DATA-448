# %% [markdown]
# # Section 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

import sys
sys.path.append('../../')

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
plt.style.use('ggplot')
sns.set_palette('Set2')

# %% [markdown]
# ## Data

# %%
team_a = pd.DataFrame({
    'Name': [ 'Brooke', 'Alex', 'Jean' ],
    'Website': [ 3, 4, 3],
    'Database': [3, 3, 3],
    'Communication': [3, 2, 2],
    'Time': [3, 1, 3]
})

display(team_a)
# Out:
#      Name  Website  Database  Communication  Time
# 0  Brooke        3         3              3     3
# 1    Alex        4         3              2     1
# 2    Jean        3         3              2     3

# %%
team_b = pd.DataFrame({
    'Name': [ 'Sky', 'Jesse', 'Sam' ],
    'Website': [5, 4, 4],
    'Database': [2, 1, 2],
    'Communication': [4, 2, 5],
    'Time': [2, 3, 1]
})

display(team_b)
# Out:
#     Name  Website  Database  Communication  Time
# 0    Sky        5         2              4     2
# 1  Jesse        4         1              2     3
# 2    Sam        4         2              5     1

# %%
team_c = pd.DataFrame({
    'Name': [ 'Andy', 'Cole', 'Blake' ],
    'Website': [2, 3, 3],
    'Database': [2, 1, 3],
    'Communication': [3, 2, 5],
    'Time': [3, 2, 3]
})

display(team_c)
# Out:
#     Name  Website  Database  Communication  Time
# 0   Andy        2         2              3     3
# 1   Cole        3         1              2     2
# 2  Blake        3         3              5     3

# %%
team_d = pd.DataFrame({
    'Name': [ 'Max', 'Devin', 'Val', 'Sid' ],
    'Website': [2, 2, 3, 1],
    'Database': [2, 1, 4, 4],
    'Communication': [1, 2, 2, 2],
    'Time': [1, 3, 3, 4]
})

display(team_d)
# Out:
#     Name  Website  Database  Communication  Time
# 0    Max        2         2              1     1
# 1  Devin        2         1              2     3
# 2    Val        3         4              2     3
# 3    Sid        1         4              2     4

# %%
class_avg = {
    'Website': 3,
    'Database': 2.4,
    'Communication': 2.7,
    'Time': 2.5,
}

display(class_avg)
# Out:
# {'Website': 3, 'Database': 2.4, 'Communication': 2.7, 'Time': 2.5}

# %% [markdown]
# ## Visualization

# %%
from functions.section1 import single_stack

single_stack.viz(team_a, class_avg, 'Website', 'TEAM A', '../../visualizations/section 1/part 1/q1/stack_a.png')
single_stack.viz(team_b, class_avg, 'Website', 'TEAM B', '../../visualizations/section 1/part 1/q1/stack_b.png')

# %%
from functions.section1 import single_bar

single_bar.viz(team_a, class_avg, 'Website', 'TEAM C', '../../visualizations/section 1/part 1/q1/bar_a.png')
single_bar.viz(team_b, class_avg, 'Website', 'TEAM D', '../../visualizations/section 1/part 1/q1/bar_b.png')
