# %%
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../../')

from functions.section2 import heat_map

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
plt.style.use('ggplot')
sns.set_palette('Set2')

# %% [markdown]
# ### Instruction
# * Arguments:
#     * csv directory
#     * title
#     * save directory
#     * do you need a tally merging to it or not (default = False)

# %%
heat_map.viz('../../data/section 2/sample data.csv', 'Interesting', '../../visualizations/section 2/temp/combined_img_heatmap.png', True)
