# %%
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../../')

from functions.section2 import grid_view as gv

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
plt.style.use('ggplot')
sns.set_palette('Set2')

# %%
gv.viz('../../data/section 2/sample data.csv','' ,'../../visualizations/section 2/temp/combined_img.png')
# Out:
# ../..\functions\section2\grid_view.py:49: UserWarning: Attempting to set identical left == right == [1.] results in singular transformations; automatically expanding.
#   plt.xlim([df.columns.values[i], df.columns.values[i]])

# %%
# Q1 (a i - ii)
# 4 members can meet at 12pm - 2pm
gv.viz('../../data/section 2/Part 1/GridView/Q1_a_whole.csv', "" ,'../../visualizations/section 2/Part 1/GridView/Q1_a_whole.png')
# Out:
# ../..\functions\section2\grid_view.py:49: UserWarning: Attempting to set identical left == right == [1.] results in singular transformations; automatically expanding.
#   plt.xlim([df.columns.values[i], df.columns.values[i]])

# %%
# Q1 (a iii)
# should use the graphs above for Q4
gv.viz('../../data/section 2/Part 1/GridView/Q1_a_iii.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_a_iii.png')

# %%
# Q1 (b i)
gv.viz('../../data/section 2/Part 1/GridView/Q1_b_i.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_b_i.png')
# Out:
# ../..\functions\section2\grid_view.py:49: UserWarning: Attempting to set identical left == right == [1.] results in singular transformations; automatically expanding.
#   plt.xlim([df.columns.values[i], df.columns.values[i]])

# %%
# Q1 (b ii)
gv.viz('../../data/section 2/Part 1/GridView/Q1_b_ii.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_b_ii.png')

# %%
# Q1 (c i)
gv.viz('../../data/section 2/Part 1/GridView/Q1_c_i.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_c_i.png')

# %%
# Q1 (c ii)
gv.viz('../../data/section 2/Part 1/GridView/Q1_c_ii.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_c_ii.png')

# %%
# Q1 (d 1a 1)
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_1a_1.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_1a_1.png')

# %%
# Q1 (d 1a 2)
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_1a_2.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_1a_2.png')

# %%
# Q1 (d 1b 1)
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_1b_1.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_1b_1.png')

# %%
# Q1 (d 1b 2)
# Probably remove 1 and 2
# Take care in tally
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_1b_2.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_1b_2.png')

# %%
# Q1 (d 1c 1)
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_1b_2.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_1c_1.png')

# %%
# Q1 (d 1c 2)
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_1c_2.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_1c_2.png')

# %%
# Q1 (d 1d 1)
# Not need to be added
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_1d_1.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_1d_1.png')

# %%
# Q1 (d 1d 2)
# not need to be added
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_1d_2.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_1d_2.png')

# %%
# Q1 (d 2a 1)
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_2a_1.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_2a_1.png')

# %%
# Q1 (d 2a 2)
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_2a_2.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_2a_2.png')

# %%
# Q1 (d 2b 1)
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_2b_1.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_2b_1.png')

# %%
# Q1 (d 2b 2)
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_2b_2.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_2b_2.png')

# %%
# Q1 (d 2c 1)
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_2c_1.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_2c_1.png')

# %%
# Q1 (d 2c 2)
gv.viz('../../data/section 2/Part 1/GridView/Q1_d_2c_2.csv', "" , '../../visualizations/section 2/Part 1/GridView/Q1_d_2c_2.png')

# %% [markdown]
# # Part 2
#
# # Issues:
# - Add team title
# - does not accomadate 3 people

# %%
# Q2 (a)
# TEAM A WITH 4 MEMBERS
gv.viz('../../data/section 2/Part 2/GridView/Team A.csv', "" , '../../visualizations/section 2/Part 2/GridView/Team A.png', need_tally = False)

# %%
# Q2 (a)
# ANSWER: Sam needs to be moved from TEAM A
gv.viz('../../data/section 2/Part 2/GridView/Team B.csv', "" , '../../visualizations/section 2/Part 2/GridView/Team B.png', need_tally=False)

# %% [markdown]
# # Part 3

# %%
# Q3 (a i)
# Scenario 1: 2 teams schedule matches
# Team A matches
gv.viz('../../data/section 2/Part 3/GridView/3a/s1_1.csv', "" , '../../visualizations/section 2/Part 3/GridView/3a/s1_1.png')
# Team B matches
gv.viz('../../data/section 2/Part 3/GridView/3a/s1_2.csv', "" , '../../visualizations/section 2/Part 3/GridView/3a/s1_2.png')
# Team C does not matches
gv.viz('../../data/section 2/Part 3/GridView/3a/s1_3.csv', "" , '../../visualizations/section 2/Part 3/GridView/3a/s1_3.png')

# %%
# Q3 (a ii)
# Scenario 2: 3 teams schedule matches
# Team A matches
gv.viz('../../data/section 2/Part 3/GridView/3a/s2_1.csv', "" , '../../visualizations/section 2/Part 3/GridView/3a/s2_1.png')
# Team B matches
gv.viz('../../data/section 2/Part 3/GridView/3a/s2_2.csv', "" , '../../visualizations/section 2/Part 3/GridView/3a/s2_2.png')
# Team C  matches
gv.viz('../../data/section 2/Part 3/GridView/3a/s2_3.csv', "" , '../../visualizations/section 2/Part 3/GridView/3a/s2_3.png')

# %%
# Q3 (b i)
# Scenario 1: 3 teams schedule matches
# Team A matches
gv.viz('../../data/section 2/Part 3/GridView/3b/s1_1.csv', "" , '../../visualizations/section 2/Part 3/GridView/3b/s1_1.png')
# Team B matches
gv.viz('../../data/section 2/Part 3/GridView/3b/s1_2.csv', "" , '../../visualizations/section 2/Part 3/GridView/3b/s1_2.png')
# Team C matches
gv.viz('../../data/section 2/Part 3/GridView/3b/s1_3.csv', "" , '../../visualizations/section 2/Part 3/GridView/3b/s1_3.png')

# %%
# Q3 (b ii)
# Scenario 2: 1 teams schedule matches
# Team A matches
gv.viz('../../data/section 2/Part 3/GridView/3b/s2_1.csv', "" , '../../visualizations/section 2/Part 3/GridView/3b/s2_1.png')
# Team B does not matches
gv.viz('../../data/section 2/Part 3/GridView/3b/s2_2.csv', "" , '../../visualizations/section 2/Part 3/GridView/3b/s2_2.png')
# Team C does not matches
gv.viz('../../data/section 2/Part 3/GridView/3b/s2_3.csv', "" , '../../visualizations/section 2/Part 3/GridView/3b/s2_3.png')

# %%
# Q3 (c i)
# Scenario 1: none of the teams schedule matches
# Team A does not matches
gv.viz('../../data/section 2/Part 3/GridView/3c/s1_1.csv', "" , '../../visualizations/section 2/Part 3/GridView/3c/s1_1.png')
# Team B does not matches
gv.viz('../../data/section 2/Part 3/GridView/3c/s1_2.csv', "" , '../../visualizations/section 2/Part 3/GridView/3c/s1_2.png')
# Team C does not matches
gv.viz('../../data/section 2/Part 3/GridView/3c/s1_3.csv', "" , '../../visualizations/section 2/Part 3/GridView/3c/s1_3.png')

# %%
# Q3 (c ii)
# Scenario 2: 3 teams schedule matches
# Team A matches
gv.viz('../../data/section 2/Part 3/GridView/3c/s2_1.csv', "" , '../../visualizations/section 2/Part 3/GridView/3c/s2_1.png')
# Team B matches
gv.viz('../../data/section 2/Part 3/GridView/3c/s2_2.csv', "" , '../../visualizations/section 2/Part 3/GridView/3c/s2_2.png')
# Team C matches
gv.viz('../../data/section 2/Part 3/GridView/3c/s2_3.csv', "" , '../../visualizations/section 2/Part 3/GridView/3c/s2_3.png')
