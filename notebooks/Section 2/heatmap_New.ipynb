# %%
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../../')

from functions.section2 import heat_map as hm

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
plt.style.use('ggplot')
sns.set_palette('Set2')

# %%
hm.viz('../../data/section 2/sample data.csv', "" , '../../visualizations/section 2/temp/combined_img.png')

# %%
# Q1 (a i - ii)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_a_whole.csv', "" , '../../visualizations/section 2/Part 1/HeatMap/Q1_a_whole.png')

# %%
# Q1 (a iii)
# use the graph above for Q20
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_a_iii.csv', "" , '../../visualizations/section 2/Part 1/HeatMap/Q1_a_iii.png')

# %%
# Q1 (b i)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_b_i.csv', "" , '../../visualizations/section 2/Part 1/HeatMap/Q1_b_i.png')

# %%
# Q1 (b ii)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_b_ii.csv', "" , '../../visualizations/section 2/Part 1/HeatMap/Q1_b_ii.png')

# %%
# Q1 (c i)
# issue with heat map
# legend only till 3 while there should be 4 members
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_c_i.csv', "" , '../../visualizations/section 2/Part 1/HeatMap/Q1_c_i.png')

# %%
# Q1 (c ii)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_c_ii.csv', "" , '../../visualizations/section 2/Part 1/HeatMap/Q1_c_ii.png')

# %%
# Q1 (d 1a 1)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_1a_1.csv', "TEAM B" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_1a_1.png')

# %%
# Q1 (d 1a 2)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_1a_2.csv', "TEAM A" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_1a_2.png')

# %%
# Q1 (d 1b 1)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_1b_1.csv', "TEAM C" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_1b_1.png')

# %%
# Q1 (d 1b 2)
# Probably remove 1 and 2
# Take care in tally
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_1b_2.csv', "TEAM D" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_1b_2.png')

# %%
# Q1 (d 1c 1)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_1c_1.csv', "TEAM A" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_1c_1.png')

# %%
# Q1 (d 1c 2)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_1c_2.csv', "TEAM B" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_1c_2.png')

# %%
# Q1 (d 1d 1)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_1d_1.csv', "TEAM A" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_1d_1.png')

# %%
# Q1 (d 1d 2)
# issue color changes according to the number of members present
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_1d_2.csv', "TEAM B" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_1d_2.png')

# %%
# Q1 (d 2a 1)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_2a_1.csv', "TEAM E" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_2a_1.png')

# %%
# Q1 (d 2a 2)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_2a_2.csv', "TEAM F" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_2a_2.png')

# %%
# Q1 (d 2b 1)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_2b_1.csv', "TEAM C" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_2b_1.png')

# %%
# Q1 (d 2b 2)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_2b_2.csv', "TEAM D" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_2b_2.png')

# %%
# Q1 (d 2c 1)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_2c_1.csv', "TEAM A" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_2c_1.png')

# %%
# Q1 (d 2c 2)
hm.viz('../../data/section 2/Part 1/HeatMap/Q1_d_2c_2.csv', "TEAM B" , '../../visualizations/section 2/Part 1/HeatMap/Q1_d_2c_2.png')

# %% [markdown]
# # Part 2
#
# # Issues:
# - Add team title
# - does not accomadate 3 people
# - Heat Map colour
# - Legend not set on 4
#
# # Solution:
#
# - Build a new function
# - Set the legend to 4
# - Cmap remove one color

# %%
# Q2 (a)
# TEAM A WITH 4 MEMBERS
hm.viz('../../data/section 2/Part 2/HeatMap/Team A.csv', "TEAM A" , '../../visualizations/section 2/Part 2/HeatMap/Team A.png')

# %%
# Q2 (a)
# TEAM B WITH 3 MEMBERS
# create another method
hm.viz('../../data/section 2/Part 2/HeatMap/Team B.csv', "TEAM B" , '../../visualizations/section 2/Part 2/HeatMap/Team B.png')

# %% [markdown]
# # Part 3

# %%
# Q3 (a i)
# Scenario 1: 3 teams schedule matches
# Team A matches
hm.viz('../../data/section 2/Part 3/HeatMap/3a/s1_1.csv', "TEAM A" , '../../visualizations/section 2/Part 3/HeatMap/3a/s1_1.png')
# Team B matches
hm.viz('../../data/section 2/Part 3/HeatMap/3a/s1_2.csv', "TEAM B" , '../../visualizations/section 2/Part 3/HeatMap/3a/s1_2.png')
# Team C matches
hm.viz('../../data/section 2/Part 3/HeatMap/3a/s1_3.csv', "TEAM C" , '../../visualizations/section 2/Part 3/HeatMap/3a/s1_3.png')

# %%
# Q3 (a ii)
# Scenario 2: 2 teams schedule matches
# Team A matches
hm.viz('../../data/section 2/Part 3/HeatMap/3a/s2_1.csv', "TEAM D" , '../../visualizations/section 2/Part 3/HeatMap/3a/s2_1.png')
# Team B does not matches
hm.viz('../../data/section 2/Part 3/HeatMap/3a/s2_2.csv', "TEAM E" , '../../visualizations/section 2/Part 3/HeatMap/3a/s2_2.png')
# Team C matches
hm.viz('../../data/section 2/Part 3/HeatMap/3a/s2_3.csv', "TEAM F" , '../../visualizations/section 2/Part 3/HeatMap/3a/s2_3.png')

# %%
# Q3 (b i)
# Scenario 1: 3 teams schedule matches
# Team A matches
hm.viz('../../data/section 2/Part 3/HeatMap/3b/s1_1.csv', "TEAM A" , '../../visualizations/section 2/Part 3/HeatMap/3b/s1_1.png')
# Team B matches
hm.viz('../../data/section 2/Part 3/HeatMap/3b/s1_2.csv', "TEAM B" , '../../visualizations/section 2/Part 3/HeatMap/3b/s1_2.png')
# Team C matches
hm.viz('../../data/section 2/Part 3/HeatMap/3b/s1_3.csv', "TEAM C" , '../../visualizations/section 2/Part 3/HeatMap/3b/s1_3.png')

# %%
# Q3 (b ii)
# Scenario 2: 1 teams schedule matches
# Team A does not matches
hm.viz('../../data/section 2/Part 3/HeatMap/3b/s2_1.csv', "TEAM D" , '../../visualizations/section 2/Part 3/HeatMap/3b/s2_1.png')
# Team B matches
hm.viz('../../data/section 2/Part 3/HeatMap/3b/s2_2.csv', "TEAM E" , '../../visualizations/section 2/Part 3/HeatMap/3b/s2_2.png')
# Team C does not matches
hm.viz('../../data/section 2/Part 3/HeatMap/3b/s2_3.csv', "TEAM F" , '../../visualizations/section 2/Part 3/HeatMap/3b/s2_3.png')

# %%
# Q3 (c i)
# Scenario 1: none of the teams schedule matches
# Team A does not matches
hm.viz('../../data/section 2/Part 3/HeatMap/3c/s1_1.csv', "TEAM A" , '../../visualizations/section 2/Part 3/HeatMap/3c/s1_1.png')
# Team B does not matches
hm.viz('../../data/section 2/Part 3/HeatMap/3c/s1_2.csv', "TEAM B" , '../../visualizations/section 2/Part 3/HeatMap/3c/s1_2.png')
# Team C does not matches
hm.viz('../../data/section 2/Part 3/HeatMap/3c/s1_3.csv', "TEAM C" , '../../visualizations/section 2/Part 3/HeatMap/3c/s1_3.png')

# %%
# Q3 (c ii)
# Scenario 2: none of the teams schedule matches
# Team A does not matches
hm.viz('../../data/section 2/Part 3/HeatMap/3c/s2_1.csv', "TEAM D" , '../../visualizations/section 2/Part 3/HeatMap/3c/s2_1.png')
# Team B does not matches
hm.viz('../../data/section 2/Part 3/HeatMap/3c/s2_2.csv', "TEAM E" , '../../visualizations/section 2/Part 3/HeatMap/3c/s2_2.png')
# Team C does not matches
hm.viz('../../data/section 2/Part 3/HeatMap/3c/s2_3.csv', "TEAM F" , '../../visualizations/section 2/Part 3/HeatMap/3c/s2_3.png')
